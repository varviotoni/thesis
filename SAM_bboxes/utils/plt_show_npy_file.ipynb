# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the .npy file
data = np.load('prediction_epoch_0.npy')

# Print basic information
print(f"Shape: {data.shape}")
print(f"Data type: {data.dtype}")
print(f"Min value: {data.min()}")
print(f"Max value: {data.max()}")

# Visualize the data (if it's a 2D array)
plt.figure(figsize=(10, 10))
plt.imshow(data)
plt.colorbar()
plt.title("Loaded from .npy file")
plt.show()
# Out:
# Shape: (1024, 1024)
# Data type: float32
# Min value: 0.06024341285228729
# Max value: 0.3527172803878784
